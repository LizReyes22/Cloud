# %%
# --- PASO 1: Instalación de paquetes
# !pip install pymongo pandas dnspython

# --- PASO 2: Importación de librerías ---
from pymongo import MongoClient
import pprint
import pandas as pd

# Configuración de PrettyPrinter
pp = pprint.PrettyPrinter(indent=4)

# --- PASO 3: Conectar a MongoDB Atlas ---
client = MongoClient("mongodb+srv://seyerliz_db_user:Mango920@cluster0.3ziw7yo.mongodb.net/")

# --- PASO 4: Conectar a la base de datos y colección ---
db = client["Redes"]           # <-- Base de datos
coleccion = db["Reason"]       # <-- Colección

# --- PASO 5: Verificar conexión ---
print(" Conectado exitosamente a MongoDB Atlas")
print(f"📂 Base de datos: {db.name}")
print(f"📄 Colección: {coleccion.name}")
print(f"📊 Documentos totales en la colección: {coleccion.count_documents({})}")

# --- PASO 6: FILTRO - Buscar tweets con sentimiento "neutral" en aerolínea ---
filter_query = {"airline_sentiment": "neutral"}
resultados = coleccion.find(filter_query) # Ejecuta la consulta

# --- PASO 7: Mostrar resultados ---
print("\n" + "="*50)
print("DOCUMENTOS CON SENTIMIENTO 'neutral':")
print("="*50)

# Mostrar los primeros 5 documentos
for i, doc in enumerate(resultados):
    if i < 5:
        print(f"\n--- Documento {i+1} ---")
        pp.pprint(doc)
    else:
        break

# --- PASO 8: Contar total ---
total_neutral = coleccion.count_documents(filter_query)
print("\n" + "="*50)
print(f"📊 TOTAL DE TWEETS NEUTRALES: {total_neutral}")
print("="*50)
# Out:
# ...
#  Conectado exitosamente a MongoDB Atlas
# 📂 Base de datos: Redes
# 📄 Colección: Reason
# 📊 Documentos totales en la colección: 14640
#
# ...
# DOCUMENTOS CON SENTIMIENTO 'neutral':
# ...
#
# --- Documento 1 ---
# {   '_id': ObjectId('6a879568d320aa8c90b6cf47'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 0.6854,
#     'airline_sentiment_gold': 'does not apply',
#     'name': 'AdamSinger',
#     'retweet_count': 0,
#     'text': "@VirginAmerica do you miss me? Don't worry we'll be together very "
#             'soon.',
#     'tweet_created': '24/02/2015 05:44',
#     'tweet_id': 5.70218e+17,
#     'tweet_location': 'San Francisco, CA',
#     'user_timezone': 'Central Time (US & Canada)'}
#
# --- Documento 2 ---
# {   '_id': ObjectId('6a879568d320aa8c90b6cf4f'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 0.6207,
#     'airline_sentiment_gold': 'does not apply',
# ...
